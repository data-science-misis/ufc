# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/data-science-misis/ufc/master/0.events_raw.csv.zip'
df_events = pd.read_csv(url)
df_events
# Out:
#       Unnamed: 0  ... winnerId
# 0              0  ...   1646.0
# 1              0  ...   1777.0
# 2              0  ...   1923.0
# 3              0  ...   1646.0
# 4              0  ...   1646.0
# ...          ...  ...      ...
# 7095           0  ...      NaN
# 7096           0  ...      NaN
# 7097           0  ...      NaN
# 7098           0  ...   2073.0
# 7099           0  ...    687.0
#
# [7100 rows x 21 columns]

# %%
url = 'https://raw.githubusercontent.com/data-science-misis/ufc/master/0.fighters_raw.csv.zip'
df_fighters = pd.read_csv(url)
df_fighters
# Out:
#       Unnamed: 0  armSpan  ... weightCategory.name wins
# 0              0   190.50  ...         Тяжелый вес   17
# 1              1   190.50  ...         Тяжелый вес    6
# 2              2   193.04  ...         Тяжелый вес   20
# 3              3   187.96  ...     Полутяжелый вес   15
# 4              4   190.50  ...     Полусредний вес   14
# ...          ...      ...  ...                 ...  ...
# 3664        3664      NaN  ...       Не определена   18
# 3665        3665      NaN  ...       Не определена   15
# 3666        3666      NaN  ...       Не определена   11
# 3667        3667      NaN  ...       Не определена   13
# 3668        3668      NaN  ...       Не определена   16
#
# [3669 rows x 39 columns]
